# %% [markdown]
# - Recently I got a lot of feedback from my dear friends who just change or about the change their career towards to Data Analysis/ Data Science and Machine Learning areas about the lack of material between beginning the analysis journey and the advanced techniques.
#
# - They are looking for detailed but at the same time beginner friendly, not so much complicated (with different regression, normalization techniques, etc.) explained Explanatory Data Analysis examples, which show them how to start and most importantly how to read the descriptive statistics and graphs.
#
# - After getting these feedbacks, I have decided to make some kind of series of EDA’s from different datasets, without making so complicated for the people at their first steps of DS/ML journey.
#
# ### This notebook is part of the 9 Beginner Friendly EDAs. If these EDAs would be helpful to anyone, I would be more than happy.

# %% [markdown]
# ### **INTRO**

# %% [markdown]
# - In this study, we are going to make Exploratory Data Analysis (EDA) with the Life Expectancy dataset.
# - Study aims to be beginner friendly and give as much as possible explanation for each step on the way.
# - Study's dataset has 3253 instances along with country name, life expectancy, and year.
# - Dataset includes life expectancy records between 1800 and 2016. 217 Years of data, quite impressive.

# %% [markdown]
# - First thing first, lets' import the related libraries for further analysis

# %%
import pandas as pd
import numpy as np

import plotly 
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

# %%
df = pd.read_csv('../input/countries-life-expectancy/Life expectancy.csv')
df.head()
# Out:
#       Entity  Year  Life expectancy
# 0  Australia  1802        34.049999
# 1  Australia  1803        34.049999
# 2  Australia  1804        34.049999
# 3  Australia  1805        34.049999
# 4  Australia  1806        34.049999

# %%
df.shape
# Out:
# (3253, 3)

# %%
df.isnull().sum()
# Out:
# Entity             0
# Year               0
# Life expectancy    0
# dtype: int64

# %%
df['Year'].unique()
# Out:
# array([1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812,
#        1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823,
#        1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834,
#        1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845,
#        1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856,
#        1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867,
#        1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878,
#        1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889,
#        1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900,
#        1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911,
#        1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922,
#        1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933,
#        1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944,
# ...

# %% [markdown]
# - We have a data between the years of 1800 and 2016.

# %%
df['Entity'].unique()
# Out:
# array(['Australia', 'Brazil', 'Canada', 'China', 'France', 'Germany',
#        'India', 'Italy', 'Japan', 'Mexico', 'Russia', 'Spain',
#        'Switzerland', 'United Kingdom', 'United States'], dtype=object)

# %% [markdown]
# - Also we have 15 different countries in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3253 entries, 0 to 3252
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Entity           3253 non-null   object
#  1   Year             3253 non-null   int64
#  2   Life expectancy  3253 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 76.4+ KB

# %% [markdown]
# - Everything seems quite OK.

# %% [markdown]
# - Let's move on to the analysis part.

# %% [markdown]
# ### Analysis Part

# %% [markdown]
# #### **Life Expectancy**

# %%
df['Life expectancy'].describe()
# Out:
# count    3253.000000
# mean       48.680380
# std        17.965669
# min         8.108836
# 25%        32.000000
# 50%        41.880001
# 75%        66.820000
# max        83.940002
# Name: Life expectancy, dtype: float64

# %% [markdown]
# - Quite expected.
# - We have 216 years of data on life expectancy from different continents and it is very normal to see skewed distribution.
# - Based on the descriptive info, we can expect highly right skewed data.
# - Let's see it

# %%
fig = px.histogram(df, x= 'Life expectancy', title='Life Expectancy', marginal="box", hover_data = df[['Entity','Year']])
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# - As we expected, even though median score is almost 42 years, distribution density increases at around 50 years.
# - And we have a quite a lot of records of life expectancy bigger than median value of life expectancy.

# %% [markdown]
# ### Life Expectancy By Year

# %%
px.scatter(df, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="da69c3ea-87fe-4744-a2d2-210993298a00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da69c3ea-87fe-4744-a2d2-210993298a00")) {                    Plotly.newPlot(                        "da69c3ea-87fe-4744-a2d2-210993298a00",                        [{"hovertemplate":"Entity=Australia<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Australia","showlegend":true,"type":"scattergl","x":[1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1844,1845,1846,184
# ...

# %% [markdown]
# - We have a lot of useful information in this scatter plot.

# %% [markdown]
# - Let's see life expectancy by year in animated version of bar chart.

# %%
fig = px.bar(df, x="Life expectancy",y="Entity", color="Entity",
  animation_frame="Year", animation_group="Entity", range_x=[0,85])
fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 30
fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 5
fig.show()
# Out:
# <div>                            <div id="2765d6ba-abc4-4747-8771-2967b751d783" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2765d6ba-abc4-4747-8771-2967b751d783")) {                    Plotly.newPlot(                        "2765d6ba-abc4-4747-8771-2967b751d783",                        [{"alignmentgroup":"True","hovertemplate":"Entity=%{y}<br>Year=1802<br>Life expectancy=%{x}<extra></extra>","ids":["Australia"],"legendgroup":"Australia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"h","showlegend":true,"textposition":"auto","type":"bar","x":[34.049999],"xaxis":"x","y":["Australia"],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Entity=%{y}<br>Year=1802<br>Life expectancy=%
# ...

# %% [markdown]
# - As seen in the both scatterplot and animated bar chart,
#    - Life expectancy is at it's lowest points at the beginning of the 1800
#    - And during the World War 1, especially at 1918
#    - and during the World War 2
#    - Significant life expectancy scores can be observed among the countries till 1950s.
#    - After 1950s, life expectancy scores start to increase significantly throughout the dataset.

# %% [markdown]
# - Let's see all of these observations closely in the different continents.

# %% [markdown]
# ### **Europe**

# %%
df_Europe = df[df['Entity'].isin(['France', 'Germany','Italy','Spain','Switzerland', 'United Kingdom'])].copy()
df_Europe["Life expectancy"].describe()
# Out:
# count    1302.000000
# mean       52.370963
# std        17.403136
# min        25.620001
# 25%        38.369999
# 50%        46.310000
# 75%        70.629736
# max        83.180000
# Name: Life expectancy, dtype: float64

# %% [markdown]
# #### Life Expectancy By Year in Europe

# %% [markdown]
# - First start with the scatterplot

# %%
px.scatter(df_Europe, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="25bad8f0-ca0a-41a1-be3f-8722eeb43dab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25bad8f0-ca0a-41a1-be3f-8722eeb43dab")) {                    Plotly.newPlot(                        "25bad8f0-ca0a-41a1-be3f-8722eeb43dab",                        [{"hovertemplate":"Entity=France<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"France","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"France","showlegend":true,"type":"scattergl","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1844,1845,1846,18
# ...

# %% [markdown]
# - In the data analysis, using visualization is very important and most of the times, if it is used effectively, it would be an excellent help for a data analyst.
#
# - In this scatter plot, during the World War 1 and World War 2, sudden decreases in the life expectancy scores can be observed clearly.

# %% [markdown]
# - Let's use animated version of the bar chart and see these changes in the action.

# %%
fig = px.bar(df_Europe, x="Life expectancy", y="Entity",color="Entity",
  animation_frame="Year", animation_group="Entity", range_x=[0,85])
fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 30
fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 5
fig.show()
# Out:
# <div>                            <div id="58b5d351-360b-418c-975d-9ed14fed1eab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58b5d351-360b-418c-975d-9ed14fed1eab")) {                    Plotly.newPlot(                        "58b5d351-360b-418c-975d-9ed14fed1eab",                        [{"alignmentgroup":"True","hovertemplate":"Entity=%{y}<br>Year=1800<br>Life expectancy=%{x}<extra></extra>","ids":["France"],"legendgroup":"France","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"h","showlegend":true,"textposition":"auto","type":"bar","x":[33.967171],"xaxis":"x","y":["France"],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Entity=%{y}<br>Year=1800<br>Life expectancy=%{x}<extra></ext
# ...

# %% [markdown]
# - Ok it is much more clear now that, in Europe, during the World War 1 and World War 2, 'life expectancy' was at the lowest points.
# - After World War 2, life expectancy increases constantly.
# - Let's get closer look at the three countries' life expectancies from the above plots.

# %% [markdown]
# #### **Germany**

# %%
germany = df_Europe[df_Europe['Entity']=='Germany'].copy()

px.scatter(germany, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="6ed93348-8835-47bf-b094-a0141a23a4c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ed93348-8835-47bf-b094-a0141a23a4c4")) {                    Plotly.newPlot(                        "6ed93348-8835-47bf-b094-a0141a23a4c4",                        [{"hovertemplate":"Entity=Germany<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"Germany","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Germany","orientation":"v","showlegend":true,"type":"scatter","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,184
# ...

# %% [markdown]
# - During the World War 1:
#    - **Germany**:
#      - Life expectancy at
#           - 1913 was 50.13,
#           - 1914 was 46.17,
#           - 1915 was 40.15,
#           - 1916 was 39.98,
#           - 1917 was 40.08
#           - and at the end of the world war 1 at 1918 was **32.93**
#
# - During the World War 2:
#     - **Germany**:
#         - Life expectancy at
#            - 1939 was 61,
#            - 1940  was 60.65,
#            - 1941 was 59,
#            - 1942 was 55,
#            - 1943 was 49.7,
#            - 1944 was **37**,
#            - at the end of the World War 2 at 1945 was **29**

# %% [markdown]
# #### **France**

# %%
france = df_Europe[df_Europe['Entity']=='France'].copy()

px.scatter(france, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="f8558751-8cf8-4721-a52b-09d41c35048b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8558751-8cf8-4721-a52b-09d41c35048b")) {                    Plotly.newPlot(                        "f8558751-8cf8-4721-a52b-09d41c35048b",                        [{"hovertemplate":"Entity=France<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"France","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"type":"scatter","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1
# ...

# %% [markdown]
# - During the World War 1:
#    - **France**:
#      - Life expectancy qt
#           - 1913 was 51.35,
#           - 1914 was 37.85,
#           - 1915 was **35.63**,
#           - 1916 was 39.81,
#           - 1917 was 42.06
#           - and at the end of the world war 1 at 1918 was **34.34**
#
# - During the World War 2:
#     - **France**:
#         - Life expectancy at
#            - 1939 was 59.62,
#            - 1940  was **49.45**,
#            - 1941 was 57.67,
#            - 1942 was 57.44,
#            - 1943 was 53.33,
#            - 1944 was **47.19**,
#            - 1945 was 54.96

# %% [markdown]
# #### **Italy**

# %%
italy = df_Europe[df_Europe['Entity']=='Italy'].copy()

px.scatter(italy, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="1d70bbea-07c1-478e-a8ac-82558ec30507" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d70bbea-07c1-478e-a8ac-82558ec30507")) {                    Plotly.newPlot(                        "1d70bbea-07c1-478e-a8ac-82558ec30507",                        [{"hovertemplate":"Entity=Italy<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"Italy","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Italy","orientation":"v","showlegend":true,"type":"scatter","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1844
# ...

# %% [markdown]
# - During the World War 1:
#    - **Italy**:
#      - Life expectancy at
#           - 1913 was 48.46,
#           - 1914 was 48.89,
#           - 1915 was 42.34,
#           - 1916 was 39.27,
#           - 1917 was 37.69
#           - and at the end of the world war 1 at 1918 was **25.62**
#
# - During the World War 2:
#     - **Italy**:
#         - Life expectancy at
#            - 1939 was 57.64,
#            - 1940  was 56.95,
#            - 1941 was 54.62,
#            - 1942 was 52.45,
#            - 1943 was **49.19**,
#            - 1944 was 52.34,
#            - at the end of the World War 2 at 1945 was 54.78

# %% [markdown]
# ### **Asia**

# %%
df_Asia = df[df['Entity'].isin(['China', 'India', 'Japan','Russia'])].copy()
df_Asia["Life expectancy"].describe()
# Out:
# count    868.000000
# mean      42.021026
# std       17.362311
# min        8.108836
# 25%       29.573458
# 50%       35.971498
# 75%       56.943000
# max       83.940002
# Name: Life expectancy, dtype: float64

# %% [markdown]
# #### Life Expectancy By Year in Asia

# %%
px.scatter(df_Asia, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="3bd2334b-1c29-4337-8e21-226ea90ba43e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bd2334b-1c29-4337-8e21-226ea90ba43e")) {                    Plotly.newPlot(                        "3bd2334b-1c29-4337-8e21-226ea90ba43e",                        [{"hovertemplate":"Entity=China<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"China","orientation":"v","showlegend":true,"type":"scatter","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1844
# ...

# %% [markdown]
# - Very similar to Europe, during the World War 1 and World War 2, changes in the life expectancy scores can be observed easily.

# %% [markdown]
# - Let's use animated version of the bar chart and see these changes in the action.

# %%
fig = px.bar(df_Asia, x="Life expectancy", y="Entity",color="Entity",
  animation_frame="Year", animation_group="Entity", range_x=[0,85])
fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 30
fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 5
fig.show()
# Out:
# <div>                            <div id="75b4e3a4-6e03-4ff7-8ba0-742ee1b353de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75b4e3a4-6e03-4ff7-8ba0-742ee1b353de")) {                    Plotly.newPlot(                        "75b4e3a4-6e03-4ff7-8ba0-742ee1b353de",                        [{"alignmentgroup":"True","hovertemplate":"Entity=%{y}<br>Year=1800<br>Life expectancy=%{x}<extra></extra>","ids":["China"],"legendgroup":"China","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"h","showlegend":true,"textposition":"auto","type":"bar","x":[32.0],"xaxis":"x","y":["China"],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Entity=%{y}<br>Year=1800<br>Life expectancy=%{x}<extra></extra>","ids"
# ...

# %% [markdown]
# - Life expectancy till World War 2, time to time significantly differs among the countries in Asia.
# - For example World War 1, except 1918, make no changes in the life expectancy in **Japan** and life expectancy continued to increase until World War 2.
# - For **Russia**, it is quite complicated. Especially between 1867 and 1946, life expectancy is significantly inconsistent.
# - On the other hand, for **India**, World War 2 makes a very slight change, compare to other countries in the Asia.
# - **China** has its own story. Between 1850-1866, between 1875-1882, betwwen 1926-1930, during the World War 2 and between 1958-1963 has quite significant changes can be observed in the life expectancy.
#
# - Let's see all of them in the plots.

# %% [markdown]
# #### **China**

# %%
china = df_Asia[df_Asia['Entity']=='China'].copy()

px.scatter(china, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="cc40eb6a-5a56-4d5b-90d3-352a59744ade" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc40eb6a-5a56-4d5b-90d3-352a59744ade")) {                    Plotly.newPlot(                        "cc40eb6a-5a56-4d5b-90d3-352a59744ade",                        [{"hovertemplate":"Entity=China<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"China","orientation":"v","showlegend":true,"type":"scatter","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1844
# ...

# %% [markdown]
# - Lowest life expectancy at 1918 was **22**

# %% [markdown]
# #### **India**

# %%
india = df_Asia[df_Asia['Entity']=='India'].copy()

px.scatter(india, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="d6867517-e2d3-4dfd-a718-9fe6485b4a6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6867517-e2d3-4dfd-a718-9fe6485b4a6c")) {                    Plotly.newPlot(                        "d6867517-e2d3-4dfd-a718-9fe6485b4a6c",                        [{"hovertemplate":"Entity=India<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"India","orientation":"v","showlegend":true,"type":"scatter","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1844
# ...

# %% [markdown]
# - Lowest life expectancy at 1918 was **8**.
# - That's quite interesting number to check with other resources.

# %% [markdown]
# #### **Japan**

# %%
japan = df_Asia[df_Asia['Entity']=='Japan'].copy()

px.scatter(japan, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="5138a29b-a61c-4533-8796-3d7bb1c98cce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5138a29b-a61c-4533-8796-3d7bb1c98cce")) {                    Plotly.newPlot(                        "5138a29b-a61c-4533-8796-3d7bb1c98cce",                        [{"hovertemplate":"Entity=Japan<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"Japan","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Japan","orientation":"v","showlegend":true,"type":"scatter","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1844
# ...

# %% [markdown]
# - Lowest life expectancy at 1945 was **30.5**

# %% [markdown]
# #### **Russia**

# %%
russia = df_Asia[df_Asia['Entity']=='Russia'].copy()

px.scatter(russia, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="13cdaaa5-7763-4588-86a4-d50fefed3eb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13cdaaa5-7763-4588-86a4-d50fefed3eb4")) {                    Plotly.newPlot(                        "13cdaaa5-7763-4588-86a4-d50fefed3eb4",                        [{"hovertemplate":"Entity=Russia<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"Russia","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Russia","orientation":"v","showlegend":true,"type":"scatter","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1
# ...

# %% [markdown]
# - Lowest life expectancy at 1943 was **16**

# %% [markdown]
# ### **America & Australia**

# %%
df_America_Australia = df[df['Entity'].isin(['Australia', 'Brazil', 'Canada', 'United States'])].copy()
df_America_Australia["Life expectancy"].describe()
# Out:
# count    866.000000
# mean      51.772170
# std       16.803706
# min       26.978191
# 25%       36.654560
# 50%       46.924160
# 75%       69.095001
# max       82.580002
# Name: Life expectancy, dtype: float64

# %%
px.scatter(df_America_Australia, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="f1d44764-eeea-475d-819d-bf0987f115b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1d44764-eeea-475d-819d-bf0987f115b6")) {                    Plotly.newPlot(                        "f1d44764-eeea-475d-819d-bf0987f115b6",                        [{"hovertemplate":"Entity=Australia<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Australia","orientation":"v","showlegend":true,"type":"scatter","x":[1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,18
# ...

# %% [markdown]
# - Scatter plot differs from the previous two scatter plots signicifacntly, especially during the World War 1 and World War 2.

# %% [markdown]
# - Let's use animated version of the bar chart and see these changes in the action.

# %%
fig = px.bar(df_America_Australia, x="Life expectancy", y="Entity",color="Entity",
  animation_frame="Year", animation_group="Entity", range_x=[0,85])
fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 30
fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 5
fig.show()
# Out:
# <div>                            <div id="0248de66-5f0b-4a44-bdda-25d0b5dc783b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0248de66-5f0b-4a44-bdda-25d0b5dc783b")) {                    Plotly.newPlot(                        "0248de66-5f0b-4a44-bdda-25d0b5dc783b",                        [{"alignmentgroup":"True","hovertemplate":"Entity=%{y}<br>Year=1802<br>Life expectancy=%{x}<extra></extra>","ids":["Australia"],"legendgroup":"Australia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"h","showlegend":true,"textposition":"auto","type":"bar","x":[34.049999],"xaxis":"x","y":["Australia"],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Entity=%{y}<br>Year=1802<br>Life expectancy=%
# ...

# %% [markdown]
# - Compare to Europe and Asia, we have a quite different life expectancy in here.
# - During the civil war (1861-1865) we can observe significant changes in the life expectancy in the **United States**. Also only in 1918, life expectancy goes down to 47.2
# - **Canada**, quite a beautiful country in every sense. Consistent increase in the life expectancy. Only in 1918, life expectancy goes down to 47.16
# - **Brazil**, consistent increase in the life expectancy can be seen after 1928. Only in 1918, life expectancy goes down to 26.97
# - **Australia**, quite similar to Canada, everything goes smoothly. Only in 1918, life expectancy goes down to 54.8
# - Let's see all of them in the plots.

# %% [markdown]
# #### **United States**

# %%
US = df_America_Australia[df_America_Australia['Entity']=='United States'].copy()

px.scatter(US, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="9390157e-308b-40bd-aeb9-1a72f18bb7cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9390157e-308b-40bd-aeb9-1a72f18bb7cd")) {                    Plotly.newPlot(                        "9390157e-308b-40bd-aeb9-1a72f18bb7cd",                        [{"hovertemplate":"Entity=United States<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"United States","orientation":"v","showlegend":true,"type":"scatter","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,
# ...

# %% [markdown]
# - Lowest life expectancy at 1864 was **31**

# %% [markdown]
# #### **Canada**

# %%
canada = df_America_Australia[df_America_Australia['Entity']=='Canada'].copy()

px.scatter(canada, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="ec2b0e7c-3794-41ee-a480-54392831e90d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec2b0e7c-3794-41ee-a480-54392831e90d")) {                    Plotly.newPlot(                        "ec2b0e7c-3794-41ee-a480-54392831e90d",                        [{"hovertemplate":"Entity=Canada<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"Canada","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Canada","orientation":"v","showlegend":true,"type":"scatter","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1
# ...

# %% [markdown]
# - Lowest life expectancy at 1800 was **39**

# %% [markdown]
# #### **Brazil**

# %%
brazil = df_America_Australia[df_America_Australia['Entity']=='Brazil'].copy()

px.scatter(brazil, x="Year", y="Life expectancy", color='Entity')
# Out:
# <div>                            <div id="cf3054e0-9d41-4f4c-8e4b-f91d40c25c76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf3054e0-9d41-4f4c-8e4b-f91d40c25c76")) {                    Plotly.newPlot(                        "cf3054e0-9d41-4f4c-8e4b-f91d40c25c76",                        [{"hovertemplate":"Entity=Brazil<br>Year=%{x}<br>Life expectancy=%{y}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Brazil","orientation":"v","showlegend":true,"type":"scatter","x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1
# ...

# %% [markdown]
# - Lowest life expectancy at 1918 was **26.97**

# %% [markdown]
# ## This notebook is a part of the 9 Beginner Friendly EDAs
# ## If you like this one, you can also check out other notebooks in the Beginner Friendly EDAs series!
#
# * [Data Analyst Jobs - EDA](https://www.kaggle.com/kaanboke/plotly-data-analyst-jobs)
# * [Top Games on Google Play Store](https://www.kaggle.com/kaanboke/plotly-beginner-friendly-top-games)
# * [Hollywood Top Movies- EDA](https://www.kaggle.com/kaanboke/plotly-beginner-friendly-top-movies)
# * [UDEMY Courses EDA](https://www.kaggle.com/kaanboke/plotly-beginner-friendly-udemy)
# * [World Happiness Report - EDA](https://www.kaggle.com/kaanboke/plotly-beginner-friendly-eda)
# * [Netflix Movies- EDA](https://www.kaggle.com/kaanboke/plotly-beginner-friendly-netflix)
# * [Amazon Top 50 Bestselling Books EDA](https://www.kaggle.com/kaanboke/plotly-beginner-friendly-amazon)
# * [London bike Sharing EDA](https://www.kaggle.com/kaanboke/plotly-beginner-friendly-london-bike)

# %% [markdown]
# - Thanks for the dataset contibutor for this data. I really enjoyed working on it.

# %% [markdown]
# - It was a quite pleasure to share with you this detailed, beginner friendly EDA. Thanks for your time.
#
# - All the best
